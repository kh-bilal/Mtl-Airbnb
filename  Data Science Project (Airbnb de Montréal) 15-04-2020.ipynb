# %% [markdown]
# ## 1. Data collection and analysis
# ### 1.1 Importing Libraries and Loading Data

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
# %matplotlib inline
import seaborn as sns
import warnings
from collections import Counter
warnings.filterwarnings('ignore')

# import and display all the columns of the dataframe
pd.pandas.set_option('display.max_columns',  None)
data_listings =pd.read_csv('listings.csv')

## print the top 3 records
data_listings.head(3)
# Out:
#       id                         listing_url       scrape_id last_scraped  \
# 0   2078   https://www.airbnb.com/rooms/2078  20200317175912   2020-03-18
# 1   2843   https://www.airbnb.com/rooms/2843  20200317175912   2020-03-18
# 2  14584  https://www.airbnb.com/rooms/14584  20200317175912   2020-03-18
#
#                                                 name  \
# 0                Central comfy close to Metro Laurie
# 1                     Fabulous downtown/airport room
# 2  Spread Out in 1,200 Square Feet of Luxury in t...
#
#                                              summary  \
# 0  Centrally located in trendy Le Plateau.   Join...
# 1  Come stay in this trendy area of downtown Mont...
# 2  This stylish and spacious loft has modern artw...
#
#                                                space  \
# 0  Centrally located  clean comfy furnished room ...
# 1  Private individual room in the downtown area, ...
# 2  It's artistic and tasteful with a modern touch...
#
#                                          description experiences_offered  \
# 0  Centrally located in trendy Le Plateau.   Join...                none
# 1  Come stay in this trendy area of downtown Mont...                none
# 2  This stylish and spacious loft has modern artw...                none
#
#                                neighborhood_overview  \
# 0  Although my place is centrally located in Le P...
# 1  This area of St Henri is actually downtown Mon...
# 2  This chic apartment can be found in the Platea...
#
#                                                notes  \
# 0  I always inform my guests the places/attractio...
# 1  From this room you can walk to downtown Montre...
# 2                                                NaN
#
#                                              transit  \
# 0  I am 6-8 mins. walk to Metro Laurie and bus ro...
# 1  There is a major metro/subway stop called Lion...
# 2                                                NaN
#
#                                               access  \
# 0  You will have full access in the apartment.  I...
# 1  The guests can use the kitchen anytime, fully ...
# 2                                                NaN
#
#                                          interaction  \
# 0  I am always available to help and give informa...
# 1  I meet guests when they arrive show them the h...
# 2                                                NaN
#
#                                          house_rules  thumbnail_url  \
# 0  No house rules but I expect my guests to follo...            NaN
# 1  No smoking and no pets Airport bus stops acros...            NaN
# 2                                                NaN            NaN
#
#    medium_url                                        picture_url  \
# 0         NaN  https://a0.muscache.com/im/pictures/88170231/0...
# 1         NaN  https://a0.muscache.com/im/pictures/397204dc-4...
# 2         NaN  https://a0.muscache.com/4ea/air/v2//pictures/0...
#
#    xl_picture_url  host_id                                 host_url host_name  \
# 0             NaN     2277   https://www.airbnb.com/users/show/2277     Nelia
# 1             NaN     2319   https://www.airbnb.com/users/show/2319      Gail
# 2             NaN    57358  https://www.airbnb.com/users/show/57358    Verona
#
#    host_since             host_location  \
# 0  2008-08-19  Montreal, Québec, Canada
# 1  2008-08-19  Montreal, Québec, Canada
# 2  2009-11-25  Montreal, Québec, Canada
#
#                                           host_about  host_response_time  \
# 0  Honest, quiet and adhere to the golden rules a...      within an hour
# 1  Manage a network of downtown rooms and private...      within an hour
# 2  I am a half Filipino/Norwegian painter living ...  within a few hours
#
#   host_response_rate host_acceptance_rate host_is_superhost  \
# 0               100%                   0%                 f
# 1               100%                 100%                 f
# 2                90%                  74%                 t
#
#                                   host_thumbnail_url  \
# 0  https://a0.muscache.com/im/users/2277/profile_...
# 1  https://a0.muscache.com/im/pictures/user/7c04e...
# 2  https://a0.muscache.com/im/users/57358/profile...
#
#                                     host_picture_url host_neighbourhood  \
# 0  https://a0.muscache.com/im/users/2277/profile_...         Le Plateau
# 1  https://a0.muscache.com/im/pictures/user/7c04e...    Little Burgundy
# 2  https://a0.muscache.com/im/users/57358/profile...         Le Plateau
#
#    host_listings_count  host_total_listings_count  \
# 0                  1.0                        1.0
# 1                  6.0                        6.0
# 2                  1.0                        1.0
#
#                                   host_verifications host_has_profile_pic  \
# 0  ['email', 'phone', 'reviews', 'manual_offline'...                    t
# 1  ['email', 'phone', 'facebook', 'reviews', 'jum...                    t
# 2  ['email', 'phone', 'facebook', 'reviews', 'man...                    t
#
#   host_identity_verified                    street          neighbourhood  \
# 0                      t      Montreal, QC, Canada  Le Plateau-Mont-Royal
# 1                      t  Montréal, Québec, Canada           Le Sud-Ouest
# 2                      t      Montreal, QC, Canada  Le Plateau-Mont-Royal
#
#   neighbourhood_cleansed  neighbourhood_group_cleansed      city   state  \
# 0  Le Plateau-Mont-Royal                           NaN  Montreal      QC
# 1           Le Sud-Ouest                           NaN  Montréal  Québec
# 2  Le Plateau-Mont-Royal                           NaN  Montreal      QC
#
#    zipcode    market    smart_location country_code country  latitude  \
# 0  H2J 3E9  Montreal  Montreal, Canada           CA  Canada  45.53069
# 1  H3J 2K3  Montreal  Montréal, Canada           CA  Canada  45.48496
# 2  H2H 2P9  Montreal  Montreal, Canada           CA  Canada  45.54135
#
#    longitude is_location_exact property_type        room_type  accommodates  \
# 0  -73.58588                 t         House     Private room             2
# 1  -73.58001                 t     Apartment     Private room             2
# 2  -73.57814                 f          Loft  Entire home/apt             4
#
#    bathrooms  bedrooms  beds  bed_type  \
# 0        1.0       1.0   1.0  Real Bed
# 1        1.0       1.0   1.0  Real Bed
# 2        1.0       1.0   1.0  Real Bed
#
#                                            amenities  square_feet    price  \
# 0  {Internet,Wifi,Kitchen,"Pets live on this prop...          NaN   $39.00
# 1  {Wifi,"Air conditioning",Kitchen,"Free street ...          NaN   $30.00
# 2  {TV,"Cable TV",Internet,Wifi,"Air conditioning...          0.0  $175.00
#
#   weekly_price monthly_price security_deposit cleaning_fee  guests_included  \
# 0      $190.00           NaN            $0.00        $0.00                1
# 1      $245.00       $650.00          $134.00       $25.00                1
# 2      $950.00     $3,000.00          $200.00        $0.00                2
#
#   extra_people  minimum_nights  maximum_nights  minimum_minimum_nights  \
# 0        $6.00               2               7                       2
# 1       $10.00               1             365                       1
# 2       $20.00               3            1125                       3
#
#    maximum_minimum_nights  minimum_maximum_nights  maximum_maximum_nights  \
# 0                       2                       7                       7
# 1                       1                     365                     365
# 2                       3                    1125                    1125
#
#    minimum_nights_avg_ntm  maximum_nights_avg_ntm calendar_updated  \
# 0                     2.0                     7.0      2 weeks ago
# 1                     1.0                   365.0       3 days ago
# 2                     3.0                  1125.0      2 weeks ago
#
#   has_availability  availability_30  availability_60  availability_90  \
# 0                t                0                0                0
# 1                t                0                0               15
# 2                t               24               52               77
#
#    availability_365 calendar_last_scraped  number_of_reviews  \
# 0                76            2020-03-18                245
# 1               286            2020-03-18                143
# 2               342            2020-03-18                175
#
#    number_of_reviews_ltm first_review last_review  review_scores_rating  \
# 0                      0   2011-09-06  2018-09-23                  93.0
# 1                     29   2009-06-20  2019-12-30                  88.0
# 2                     30   2011-06-06  2020-03-01                  98.0
#
#    review_scores_accuracy  review_scores_cleanliness  review_scores_checkin  \
# 0                    10.0                        9.0                   10.0
# 1                     9.0                        9.0                    9.0
# 2                    10.0                       10.0                   10.0
#
#    review_scores_communication  review_scores_location  review_scores_value  \
# 0                         10.0                    10.0                 10.0
# 1                          9.0                    10.0                 10.0
# 2                         10.0                    10.0                 10.0
#
#   requires_license  license jurisdiction_names instant_bookable  \
# 0                f      NaN     {Quebec," CA"}                t
# 1                f      NaN     {Quebec," CA"}                t
# 2                f      NaN     {Quebec," CA"}                f
#
#   is_business_travel_ready          cancellation_policy  \
# 0                        f                     flexible
# 1                        f                     moderate
# 2                        f  strict_14_with_grace_period
#
#   require_guest_profile_picture require_guest_phone_verification  \
# 0                             f                                f
# 1                             f                                f
# 2                             f                                f
#
#    calculated_host_listings_count  \
# 0                               1
# 1                               6
# 2                               1
#
#    calculated_host_listings_count_entire_homes  \
# 0                                            0
# 1                                            3
# 2                                            1
#
#    calculated_host_listings_count_private_rooms  \
# 0                                             1
# 1                                             3
# 2                                             0
#
#    calculated_host_listings_count_shared_rooms  reviews_per_month
# 0                                            0               2.36
# 1                                            0               1.09
# 2                                            0               1.64

# %%
# convert price type to float
data_listings['price'] = data_listings['price'].str.replace('$','')
data_listings['price'] = data_listings['price'].str.replace(',','')
data_listings['price'] = data_listings['price'].astype(float)

# %% [markdown]
# ##### Split data betweeen test_set and train_set

# %%
# Print the shape of dataset with rows and columns
print('data set shape', data_listings.shape)

from sklearn.model_selection import train_test_split
train, test = train_test_split(data_listings, test_size = 0.2, random_state = 42)
print('train set shape', train.shape)
print('test set shape', test.shape)
# Out:
# data set shape (20176, 106)
# train set shape (16140, 106)
# test set shape (4036, 106)

# %% [markdown]
# ### 1.2 Data analysis and cleaning

# %% [markdown]
# #### Missing Categorial features Values

# %%
## Here we will check the percentage of nan categorical values present in each feature

montreal_listing = pd.DataFrame()
montreal_listing = train.copy()

## 1 - step make the list of Categorial features wich has missing values 
features_with_NAN = [feature for feature in montreal_listing.columns if montreal_listing[feature].isnull().sum()>1 and montreal_listing[feature].dtypes=='O']
 
## 2 - step print the feature name and the percentage of missing values
for feature in features_with_NAN:
    print(feature, np.round(montreal_listing[feature].isnull().mean()*100, 4),'% missing values')
# Out:
# name 0.0929 % missing values
# summary 4.7336 % missing values
# space 33.544 % missing values
# description 2.8625 % missing values
# neighborhood_overview 38.1413 % missing values
# notes 64.1512 % missing values
# transit 38.0731 % missing values
# access 51.4994 % missing values
# interaction 45.3965 % missing values
# house_rules 44.1264 % missing values
# host_name 0.0248 % missing values
# host_since 0.0248 % missing values
# host_location 0.1301 % missing values
# host_about 45.0372 % missing values
# host_response_time 40.0372 % missing values
# host_response_rate 40.0372 % missing values
# host_acceptance_rate 28.1413 % missing values
# host_is_superhost 0.0248 % missing values
# host_thumbnail_url 0.0248 % missing values
# host_picture_url 0.0248 % missing values
# host_neighbourhood 13.4263 % missing values
# host_has_profile_pic 0.0248 % missing values
# host_identity_verified 0.0248 % missing values
# neighbourhood 0.2107 % missing values
# city 0.0248 % missing values
# state 0.4957 % missing values
# zipcode 1.4746 % missing values
# market 0.2478 % missing values
# weekly_price 88.7299 % missing values
# monthly_price 90.2912 % missing values
# security_deposit 33.9219 % missing values
# cleaning_fee 24.0582 % missing values
# first_review 20.285 % missing values
# last_review 20.285 % missing values
# jurisdiction_names 0.0558 % missing values

# %%
## Replace missing value with a new label ('Missing')
def replace_cat_feature(dataset,features_with_NAN):
    data=montreal_listing.copy()
    data[features_with_NAN]=data[features_with_NAN].fillna('Missing')
    return data

montreal_listing=replace_cat_feature(montreal_listing,features_with_NAN)

montreal_listing[features_with_NAN].isnull().sum()
# Out:
# name                      0
# summary                   0
# space                     0
# description               0
# neighborhood_overview     0
# notes                     0
# transit                   0
# access                    0
# interaction               0
# house_rules               0
# host_name                 0
# host_since                0
# host_location             0
# host_about                0
# host_response_time        0
# host_response_rate        0
# host_acceptance_rate      0
# host_is_superhost         0
# host_thumbnail_url        0
# host_picture_url          0
# host_neighbourhood        0
# host_has_profile_pic      0
# host_identity_verified    0
# neighbourhood             0
# city                      0
# state                     0
# zipcode                   0
# market                    0
# weekly_price              0
# monthly_price             0
# security_deposit          0
# cleaning_fee              0
# first_review              0
# last_review               0
# jurisdiction_names        0
# dtype: int64

# %%
montreal_listing.head(2)
# Out:
#              id                            listing_url       scrape_id  \
# 17188  38905522  https://www.airbnb.com/rooms/38905522  20200317175912
# 9902   23857896  https://www.airbnb.com/rooms/23857896  20200317175912
#
#       last_scraped                                        name  \
# 17188   2020-03-17                            Au bord de l’eau
# 9902    2020-03-17  Lovely, cozy & clean apartment in Rosemont
#
#                                                  summary    space  \
# 17188                                            Missing  Missing
# 9902   Lovely, cozy and clean apartment in Rosemont !...  Missing
#
#                                              description experiences_offered  \
# 17188                                            Missing                none
# 9902   Lovely, cozy and clean apartment in Rosemont !...                none
#
#       neighborhood_overview    notes  transit   access interaction  \
# 17188               Missing  Missing  Missing  Missing     Missing
# 9902                Missing  Missing  Missing  Missing     Missing
#
#       house_rules  thumbnail_url  medium_url  \
# 17188     Missing            NaN         NaN
# 9902      Missing            NaN         NaN
#
#                                              picture_url  xl_picture_url  \
# 17188  https://a0.muscache.com/im/pictures/b819c456-2...             NaN
# 9902   https://a0.muscache.com/im/pictures/1445c7db-d...             NaN
#
#          host_id                                     host_url  host_name  \
# 17188  297959654  https://www.airbnb.com/users/show/297959654  Jean-René
# 9902    42838352   https://www.airbnb.com/users/show/42838352   Caroline
#
#        host_since             host_location host_about host_response_time  \
# 17188  2019-09-25  Montreal, Quebec, Canada    Missing       within a day
# 9902   2015-08-29  Montreal, Quebec, Canada    Missing            Missing
#
#       host_response_rate host_acceptance_rate host_is_superhost  \
# 17188               100%              Missing                 f
# 9902             Missing              Missing                 f
#
#                                       host_thumbnail_url  \
# 17188  https://a0.muscache.com/im/pictures/user/70ccf...
# 9902   https://a0.muscache.com/im/users/42838352/prof...
#
#                                         host_picture_url host_neighbourhood  \
# 17188  https://a0.muscache.com/im/pictures/user/70ccf...            Missing
# 9902   https://a0.muscache.com/im/users/42838352/prof...   La Petite-Patrie
#
#        host_listings_count  host_total_listings_count  \
# 17188                  1.0                        1.0
# 9902                   1.0                        1.0
#
#                                       host_verifications host_has_profile_pic  \
# 17188  ['email', 'phone', 'offline_government_id', 's...                    t
# 9902   ['email', 'phone', 'reviews', 'offline_governm...                    t
#
#       host_identity_verified                    street  \
# 17188                      f      Montréal, QC, Canada
# 9902                       t  Montréal, Québec, Canada
#
#                    neighbourhood         neighbourhood_cleansed  \
# 17188               L'Ile-Bizard  L'Île-Bizard-Sainte-Geneviève
# 9902   Rosemont-La Petite-Patrie      Rosemont-La Petite-Patrie
#
#        neighbourhood_group_cleansed      city   state  zipcode    market  \
# 17188                           NaN  Montréal      QC  H9C 1L5  Montreal
# 9902                            NaN  Montréal  Québec  H2S 2E2  Montreal
#
#          smart_location country_code country  latitude  longitude  \
# 17188  Montréal, Canada           CA  Canada  45.48747  -73.87702
# 9902   Montréal, Canada           CA  Canada  45.53846  -73.60068
#
#       is_location_exact      property_type        room_type  accommodates  \
# 17188                 f  Bed and breakfast     Private room             2
# 9902                  t          Apartment  Entire home/apt             4
#
#        bathrooms  bedrooms  beds  bed_type  \
# 17188        1.0       1.0   1.0  Real Bed
# 9902         1.0       0.0   1.0  Real Bed
#
#                                                amenities  square_feet  price  \
# 17188  {TV,Wifi,Kitchen,"Free parking on premises",He...          NaN   63.0
# 9902   {Wifi,Kitchen,Heating,Washer,Dryer,"Smoke dete...          NaN   52.0
#
#       weekly_price monthly_price security_deposit cleaning_fee  \
# 17188      Missing       Missing          Missing      Missing
# 9902       Missing       Missing          Missing      Missing
#
#        guests_included extra_people  minimum_nights  maximum_nights  \
# 17188                1        $0.00               1            1125
# 9902                 1        $0.00               1            1125
#
#        minimum_minimum_nights  maximum_minimum_nights  minimum_maximum_nights  \
# 17188                       1                       1                    1125
# 9902                        1                       1                    1125
#
#        maximum_maximum_nights  minimum_nights_avg_ntm  maximum_nights_avg_ntm  \
# 17188                    1125                     1.0                  1125.0
# 9902                     1125                     1.0                  1125.0
#
#       calendar_updated has_availability  availability_30  availability_60  \
# 17188     5 months ago                t                0                0
# 9902     24 months ago                t                0                0
#
#        availability_90  availability_365 calendar_last_scraped  \
# 17188                0                 0            2020-03-17
# 9902                 0                 0            2020-03-17
#
#        number_of_reviews  number_of_reviews_ltm first_review last_review  \
# 17188                  0                      0      Missing     Missing
# 9902                   3                      0   2018-04-01  2018-04-08
#
#        review_scores_rating  review_scores_accuracy  \
# 17188                   NaN                     NaN
# 9902                   93.0                    10.0
#
#        review_scores_cleanliness  review_scores_checkin  \
# 17188                        NaN                    NaN
# 9902                         9.0                   10.0
#
#        review_scores_communication  review_scores_location  \
# 17188                          NaN                     NaN
# 9902                          10.0                     9.0
#
#        review_scores_value requires_license  license jurisdiction_names  \
# 17188                  NaN                f      NaN     {Quebec," CA"}
# 9902                   9.0                f      NaN     {Quebec," CA"}
#
#       instant_bookable is_business_travel_ready cancellation_policy  \
# 17188                t                        f            flexible
# 9902                 t                        f            flexible
#
#       require_guest_profile_picture require_guest_phone_verification  \
# 17188                             f                                f
# 9902                              f                                f
#
#        calculated_host_listings_count  \
# 17188                               1
# 9902                                1
#
#        calculated_host_listings_count_entire_homes  \
# 17188                                            0
# 9902                                             1
#
#        calculated_host_listings_count_private_rooms  \
# 17188                                             1
# 9902                                              0
#
#        calculated_host_listings_count_shared_rooms  reviews_per_month
# 17188                                            0                NaN
# 9902                                             0               0.13

# %% [markdown]
# #### Missing numerical features Values

# %%
## Here we will check the percentage of nan numerical values present in each feature

montreal_listing = pd.DataFrame()
montreal_listing = train.copy()

## 1 - step make the list of Categorial features wich has missing values 
features_numerical_with_NAN = [feature for feature in montreal_listing.columns if montreal_listing[feature].isnull().sum()>1 and montreal_listing[feature].dtypes !='O']
 
## 2 - step print the feature name and the percentage of missing values
for feature in features_numerical_with_NAN:
    print(feature, np.round(montreal_listing[feature].isnull().mean()*100, 4),'% missing values')
# Out:
# thumbnail_url 100.0 % missing values
# medium_url 100.0 % missing values
# xl_picture_url 100.0 % missing values
# host_listings_count 0.0248 % missing values
# host_total_listings_count 0.0248 % missing values
# neighbourhood_group_cleansed 100.0 % missing values
# bathrooms 0.1239 % missing values
# bedrooms 0.1673 % missing values
# beds 0.7373 % missing values
# square_feet 98.8476 % missing values
# review_scores_rating 22.2429 % missing values
# review_scores_accuracy 22.3296 % missing values
# review_scores_cleanliness 22.3234 % missing values
# review_scores_checkin 22.3544 % missing values
# review_scores_communication 22.3048 % missing values
# review_scores_location 22.3606 % missing values
# review_scores_value 22.3854 % missing values
# license 100.0 % missing values
# reviews_per_month 20.285 % missing values

# %%
## Replacing the numerical Missing Values
dataset = montreal_listing.copy()
for feature in features_numerical_with_NAN:
    ## We will replace by using median since there are outliers
    median_value=dataset[feature].median()
    
    ## create a new feature to capture nan values
    dataset[feature+'nan']=np.where(dataset[feature].isnull(),1,0)
    dataset[feature].fillna(median_value,inplace=True)
    
dataset[features_numerical_with_NAN].isnull().sum()
# Out:
# thumbnail_url                   16140
# medium_url                      16140
# xl_picture_url                  16140
# host_listings_count                 0
# host_total_listings_count           0
# neighbourhood_group_cleansed    16140
# bathrooms                           0
# bedrooms                            0
# beds                                0
# square_feet                         0
# review_scores_rating                0
# review_scores_accuracy              0
# review_scores_cleanliness           0
# review_scores_checkin               0
# review_scores_communication         0
# review_scores_location              0
# review_scores_value                 0
# license                         16140
# reviews_per_month                   0
# dtype: int64

# %%
dataset.shape
# Out:
# (16140, 125)

# %% [markdown]
# #### Not interesting features

# %%
### drop 100% features_numerical_with_NAN nan values 
dataset.drop(['thumbnail_url','medium_url','xl_picture_url','neighbourhood_group_cleansed','license'],axis=1,inplace=True)

## drop host_since
dataset.drop(['host_since'],axis=1,inplace=True)

## drop Not interesting features
dataset.drop(['id','listing_url','scrape_id','last_scraped', 'picture_url', 'host_url', 'host_name','host_thumbnail_url','host_picture_url','state', 'calendar_last_scraped','first_review', 'last_review'],axis=1,inplace=True)

# %%
dataset.shape
# Out:
# (16140, 106)

# %% [markdown]
# #### Handling Rare Categorical Feature

# %% [markdown]
# We will remove categorical variables that are present less than 1% of the observation and convert to a new label 'Rare_var'

# %%
categorical_features=[feature for feature in dataset.columns if dataset[feature].dtype=='O']

for feature in categorical_features:
    temp=dataset.groupby(feature)['price'].count()/len(dataset)
    temp_df=temp[temp>0.01].index
    dataset[feature]=np.where(dataset[feature].isin(temp_df),dataset[feature],'Rare_var')
    
dataset.head(4)
# Out:
#            name   summary     space description experiences_offered  \
# 17188  Rare_var  Rare_var  Rare_var    Rare_var                none
# 9902   Rare_var  Rare_var  Rare_var    Rare_var                none
# 17796  Rare_var  Rare_var  Rare_var    Rare_var                none
# 16947  Rare_var  Rare_var  Rare_var    Rare_var                none
#
#       neighborhood_overview     notes   transit    access interaction  \
# 17188              Rare_var  Rare_var  Rare_var  Rare_var    Rare_var
# 9902               Rare_var  Rare_var  Rare_var  Rare_var    Rare_var
# 17796              Rare_var  Rare_var  Rare_var  Rare_var    Rare_var
# 16947              Rare_var  Rare_var  Rare_var  Rare_var    Rare_var
#
#       house_rules    host_id             host_location host_about  \
# 17188    Rare_var  297959654  Montreal, Quebec, Canada   Rare_var
# 9902     Rare_var   42838352  Montreal, Quebec, Canada   Rare_var
# 17796    Rare_var  305316366                        CA   Rare_var
# 16947    Rare_var  146937818  Montreal, Quebec, Canada   Rare_var
#
#       host_response_time host_response_rate host_acceptance_rate  \
# 17188       within a day               100%             Rare_var
# 9902            Rare_var           Rare_var             Rare_var
# 17796     within an hour           Rare_var                 100%
# 16947     within an hour               100%                 100%
#
#       host_is_superhost       host_neighbourhood  host_listings_count  \
# 17188                 f                 Rare_var                  1.0
# 9902                  f         La Petite-Patrie                  1.0
# 17796                 f  Quartier des Spectacles                 13.0
# 16947                 t                 Rare_var                  1.0
#
#        host_total_listings_count  \
# 17188                        1.0
# 9902                         1.0
# 17796                       13.0
# 16947                        1.0
#
#                                       host_verifications host_has_profile_pic  \
# 17188  ['email', 'phone', 'offline_government_id', 's...                    t
# 9902                                            Rare_var                    t
# 17796  ['email', 'phone', 'offline_government_id', 's...                    t
# 16947  ['email', 'phone', 'offline_government_id', 's...                    t
#
#       host_identity_verified                    street  \
# 17188                      f      Montréal, QC, Canada
# 9902                       t  Montréal, Québec, Canada
# 17796                      t  Montréal, Québec, Canada
# 16947                      f      Montréal, QC, Canada
#
#                    neighbourhood               neighbourhood_cleansed  \
# 17188                   Rare_var                             Rare_var
# 9902   Rosemont-La Petite-Patrie            Rosemont-La Petite-Patrie
# 17796        Notre-Dame-de-Grace  Côte-des-Neiges-Notre-Dame-de-Grâce
# 16947                   Rare_var                             Rare_var
#
#            city   zipcode    market    smart_location country_code country  \
# 17188  Montréal  Rare_var  Montreal  Montréal, Canada           CA  Canada
# 9902   Montréal  Rare_var  Montreal  Montréal, Canada           CA  Canada
# 17796  Montréal  Rare_var  Montreal  Montréal, Canada           CA  Canada
# 16947  Montréal  Rare_var  Rare_var  Montréal, Canada           CA  Canada
#
#        latitude  longitude is_location_exact property_type        room_type  \
# 17188  45.48747  -73.87702                 f      Rare_var     Private room
# 9902   45.53846  -73.60068                 t     Apartment  Entire home/apt
# 17796  45.46066  -73.64763                 t         House  Entire home/apt
# 16947  45.65518  -73.57457                 t     Apartment     Private room
#
#        accommodates  bathrooms  bedrooms  beds  bed_type amenities  \
# 17188             2        1.0       1.0   1.0  Real Bed  Rare_var
# 9902              4        1.0       0.0   1.0  Real Bed  Rare_var
# 17796             4        1.5       2.0   2.0  Real Bed  Rare_var
# 16947             2        1.5       1.0   1.0  Real Bed  Rare_var
#
#        square_feet  price weekly_price monthly_price security_deposit  \
# 17188        207.5   63.0     Rare_var      Rare_var         Rare_var
# 9902         207.5   52.0     Rare_var      Rare_var         Rare_var
# 17796        207.5  118.0     Rare_var      Rare_var            $0.00
# 16947        207.5   75.0     Rare_var      Rare_var         Rare_var
#
#       cleaning_fee  guests_included extra_people  minimum_nights  \
# 17188     Rare_var                1        $0.00               1
# 9902      Rare_var                1        $0.00               1
# 17796     Rare_var                4        $0.00               1
# 16947     Rare_var                1        $0.00               2
#
#        maximum_nights  minimum_minimum_nights  maximum_minimum_nights  \
# 17188            1125                       1                       1
# 9902             1125                       1                       1
# 17796              30                       1                       2
# 16947            1125                       2                       2
#
#        minimum_maximum_nights  maximum_maximum_nights  minimum_nights_avg_ntm  \
# 17188                    1125                    1125                     1.0
# 9902                     1125                    1125                     1.0
# 17796                      30                      30                     1.8
# 16947                    1125                    1125                     2.0
#
#        maximum_nights_avg_ntm calendar_updated has_availability  \
# 17188                  1125.0     5 months ago                t
# 9902                   1125.0         Rare_var                t
# 17796                    30.0      2 weeks ago                t
# 16947                  1125.0     6 months ago                t
#
#        availability_30  availability_60  availability_90  availability_365  \
# 17188                0                0                0                 0
# 9902                 0                0                0                 0
# 17796               30               60               90               364
# 16947               30               60               90               180
#
#        number_of_reviews  number_of_reviews_ltm  review_scores_rating  \
# 17188                  0                      0                  96.0
# 9902                   3                      0                  93.0
# 17796                  0                      0                  96.0
# 16947                  0                      0                  96.0
#
#        review_scores_accuracy  review_scores_cleanliness  \
# 17188                    10.0                       10.0
# 9902                     10.0                        9.0
# 17796                    10.0                       10.0
# 16947                    10.0                       10.0
#
#        review_scores_checkin  review_scores_communication  \
# 17188                   10.0                         10.0
# 9902                    10.0                         10.0
# 17796                   10.0                         10.0
# 16947                   10.0                         10.0
#
#        review_scores_location  review_scores_value requires_license  \
# 17188                    10.0                 10.0                f
# 9902                      9.0                  9.0                f
# 17796                    10.0                 10.0                f
# 16947                    10.0                 10.0                f
#
#       jurisdiction_names instant_bookable is_business_travel_ready  \
# 17188     {Quebec," CA"}                t                        f
# 9902      {Quebec," CA"}                t                        f
# 17796     {Quebec," CA"}                t                        f
# 16947     {Quebec," CA"}                t                        f
#
#       cancellation_policy require_guest_profile_picture  \
# 17188            flexible                             f
# 9902             flexible                             f
# 17796            moderate                             f
# 16947            flexible                             f
#
#       require_guest_phone_verification  calculated_host_listings_count  \
# 17188                                f                               1
# 9902                                 f                               1
# 17796                                f                               8
# 16947                                f                               2
#
#        calculated_host_listings_count_entire_homes  \
# 17188                                            0
# 9902                                             1
# 17796                                            8
# 16947                                            1
#
#        calculated_host_listings_count_private_rooms  \
# 17188                                             1
# 9902                                              0
# 17796                                             0
# 16947                                             1
#
#        calculated_host_listings_count_shared_rooms  reviews_per_month  \
# 17188                                            0               0.63
# 9902                                             0               0.13
# 17796                                            0               0.63
# 16947                                            0               0.63
#
#        thumbnail_urlnan  medium_urlnan  xl_picture_urlnan  \
# 17188                 1              1                  1
# 9902                  1              1                  1
# 17796                 1              1                  1
# 16947                 1              1                  1
#
#        host_listings_countnan  host_total_listings_countnan  \
# 17188                       0                             0
# 9902                        0                             0
# 17796                       0                             0
# 16947                       0                             0
#
#        neighbourhood_group_cleansednan  bathroomsnan  bedroomsnan  bedsnan  \
# 17188                                1             0            0        0
# 9902                                 1             0            0        0
# 17796                                1             0            0        0
# 16947                                1             0            0        0
#
#        square_feetnan  review_scores_ratingnan  review_scores_accuracynan  \
# 17188               1                        1                          1
# 9902                1                        0                          0
# 17796               1                        1                          1
# 16947               1                        1                          1
#
#        review_scores_cleanlinessnan  review_scores_checkinnan  \
# 17188                             1                         1
# 9902                              0                         0
# 17796                             1                         1
# 16947                             1                         1
#
#        review_scores_communicationnan  review_scores_locationnan  \
# 17188                               1                          1
# 9902                                0                          0
# 17796                               1                          1
# 16947                               1                          1
#
#        review_scores_valuenan  licensenan  reviews_per_monthnan
# 17188                       1           1                     1
# 9902                        0           1                     0
# 17796                       1           1                     1
# 16947                       1           1                     1

# %%
dataset.bed_type.value_counts()
# Out:
# Real Bed    15970
# Rare_var      170
# Name: bed_type, dtype: int64

# %% [markdown]
# ### Handele categorical Features

# %%
# Encoding categorical features 
for feature in categorical_features:
    labels_ordered=dataset.groupby([feature])['price'].mean().sort_values().index
    labels_ordered={k:i for i,k in enumerate(labels_ordered,0)}
    dataset[feature]=dataset[feature].map(labels_ordered)
    
dataset.head()
# Out:
#        name  summary  space  description  experiences_offered  \
# 17188     0        0      0            0                    0
# 9902      0        0      0            0                    0
# 17796     0        0      0            0                    0
# 16947     0        0      0            0                    0
# 18192     0        0      0            0                    0
#
#        neighborhood_overview  notes  transit  access  interaction  \
# 17188                      0      0        0       0            0
# 9902                       0      0        0       0            0
# 17796                      0      0        0       0            0
# 16947                      0      0        0       0            0
# 18192                      0      0        0       0            0
#
#        house_rules    host_id  host_location  host_about  host_response_time  \
# 17188            0  297959654              1           0                   2
# 9902             0   42838352              1           0                   0
# 17796            0  305316366              3           0                   3
# 16947            0  146937818              1           0                   3
# 18192            0  311505714              3           0                   3
#
#        host_response_rate  host_acceptance_rate  host_is_superhost  \
# 17188                   2                     2                  1
# 9902                    0                     2                  1
# 17796                   0                     4                  1
# 16947                   2                     4                  2
# 18192                   2                     4                  1
#
#        host_neighbourhood  host_listings_count  host_total_listings_count  \
# 17188                  17                  1.0                        1.0
# 9902                   14                  1.0                        1.0
# 17796                  19                 13.0                       13.0
# 16947                  17                  1.0                        1.0
# 18192                   0                 14.0                       14.0
#
#        host_verifications  host_has_profile_pic  host_identity_verified  \
# 17188                  11                     1                       2
# 9902                    6                     1                       1
# 17796                  11                     1                       1
# 16947                  11                     1                       2
# 18192                  21                     1                       2
#
#        street  neighbourhood  neighbourhood_cleansed  city  zipcode  market  \
# 17188       2             19                       9     0        0       1
# 9902        1              9                       6     0        0       1
# 17796       1             20                       5     0        0       1
# 16947       2             19                       9     0        0       0
# 18192       2             11                       8     0        0       1
#
#        smart_location  country_code  country  latitude  longitude  \
# 17188               0             1        1  45.48747  -73.87702
# 9902                0             1        1  45.53846  -73.60068
# 17796               0             1        1  45.46066  -73.64763
# 16947               0             1        1  45.65518  -73.57457
# 18192               0             1        1  45.45209  -73.59023
#
#        is_location_exact  property_type  room_type  accommodates  bathrooms  \
# 17188                  0              3          0             2        1.0
# 9902                   1              0          2             4        1.0
# 17796                  1              2          2             4        1.5
# 16947                  1              0          0             2        1.5
# 18192                  1              2          0             1        2.0
#
#        bedrooms  beds  bed_type  amenities  square_feet  price  weekly_price  \
# 17188       1.0   1.0         1          0        207.5   63.0             0
# 9902        0.0   1.0         1          0        207.5   52.0             0
# 17796       2.0   2.0         1          0        207.5  118.0             0
# 16947       1.0   1.0         1          0        207.5   75.0             0
# 18192       1.0   2.0         1          0        207.5   25.0             0
#
#        monthly_price  security_deposit  cleaning_fee  guests_included  \
# 17188              0                 4            15                1
# 9902               0                 4            15                1
# 17796              0                 1            15                4
# 16947              0                 4            15                1
# 18192              0                 4            12                1
#
#        extra_people  minimum_nights  maximum_nights  minimum_minimum_nights  \
# 17188             4               1            1125                       1
# 9902              4               1            1125                       1
# 17796             4               1              30                       1
# 16947             4               2            1125                       2
# 18192             4              32             124                      32
#
#        maximum_minimum_nights  minimum_maximum_nights  maximum_maximum_nights  \
# 17188                       1                    1125                    1125
# 9902                        1                    1125                    1125
# 17796                       2                      30                      30
# 16947                       2                    1125                    1125
# 18192                      32                     124                     124
#
#        minimum_nights_avg_ntm  maximum_nights_avg_ntm  calendar_updated  \
# 17188                     1.0                  1125.0                 7
# 9902                      1.0                  1125.0                 1
# 17796                     1.8                    30.0                 9
# 16947                     2.0                  1125.0                 5
# 18192                    32.0                   124.0                15
#
#        has_availability  availability_30  availability_60  availability_90  \
# 17188                 0                0                0                0
# 9902                  0                0                0                0
# 17796                 0               30               60               90
# 16947                 0               30               60               90
# 18192                 0               12               25               38
#
#        availability_365  number_of_reviews  number_of_reviews_ltm  \
# 17188                 0                  0                      0
# 9902                  0                  3                      0
# 17796               364                  0                      0
# 16947               180                  0                      0
# 18192                38                  0                      0
#
#        review_scores_rating  review_scores_accuracy  \
# 17188                  96.0                    10.0
# 9902                   93.0                    10.0
# 17796                  96.0                    10.0
# 16947                  96.0                    10.0
# 18192                  96.0                    10.0
#
#        review_scores_cleanliness  review_scores_checkin  \
# 17188                       10.0                   10.0
# 9902                         9.0                   10.0
# 17796                       10.0                   10.0
# 16947                       10.0                   10.0
# 18192                       10.0                   10.0
#
#        review_scores_communication  review_scores_location  \
# 17188                         10.0                    10.0
# 9902                          10.0                     9.0
# 17796                         10.0                    10.0
# 16947                         10.0                    10.0
# 18192                         10.0                    10.0
#
#        review_scores_value  requires_license  jurisdiction_names  \
# 17188                 10.0                 1                   0
# 9902                   9.0                 1                   0
# 17796                 10.0                 1                   0
# 16947                 10.0                 1                   0
# 18192                 10.0                 1                   0
#
#        instant_bookable  is_business_travel_ready  cancellation_policy  \
# 17188                 0                         0                    1
# 9902                  0                         0                    1
# 17796                 0                         0                    0
# 16947                 0                         0                    1
# 18192                 0                         0                    0
#
#        require_guest_profile_picture  require_guest_phone_verification  \
# 17188                              0                                 0
# 9902                               0                                 0
# 17796                              0                                 0
# 16947                              0                                 0
# 18192                              0                                 0
#
#        calculated_host_listings_count  \
# 17188                               1
# 9902                                1
# 17796                               8
# 16947                               2
# 18192                              14
#
#        calculated_host_listings_count_entire_homes  \
# 17188                                            0
# 9902                                             1
# 17796                                            8
# 16947                                            1
# 18192                                            0
#
#        calculated_host_listings_count_private_rooms  \
# 17188                                             1
# 9902                                              0
# 17796                                             0
# 16947                                             1
# 18192                                            14
#
#        calculated_host_listings_count_shared_rooms  reviews_per_month  \
# 17188                                            0               0.63
# 9902                                             0               0.13
# 17796                                            0               0.63
# 16947                                            0               0.63
# 18192                                            0               0.63
#
#        thumbnail_urlnan  medium_urlnan  xl_picture_urlnan  \
# 17188                 1              1                  1
# 9902                  1              1                  1
# 17796                 1              1                  1
# 16947                 1              1                  1
# 18192                 1              1                  1
#
#        host_listings_countnan  host_total_listings_countnan  \
# 17188                       0                             0
# 9902                        0                             0
# 17796                       0                             0
# 16947                       0                             0
# 18192                       0                             0
#
#        neighbourhood_group_cleansednan  bathroomsnan  bedroomsnan  bedsnan  \
# 17188                                1             0            0        0
# 9902                                 1             0            0        0
# 17796                                1             0            0        0
# 16947                                1             0            0        0
# 18192                                1             0            0        0
#
#        square_feetnan  review_scores_ratingnan  review_scores_accuracynan  \
# 17188               1                        1                          1
# 9902                1                        0                          0
# 17796               1                        1                          1
# 16947               1                        1                          1
# 18192               1                        1                          1
#
#        review_scores_cleanlinessnan  review_scores_checkinnan  \
# 17188                             1                         1
# 9902                              0                         0
# 17796                             1                         1
# 16947                             1                         1
# 18192                             1                         1
#
#        review_scores_communicationnan  review_scores_locationnan  \
# 17188                               1                          1
# 9902                                0                          0
# 17796                               1                          1
# 16947                               1                          1
# 18192                               1                          1
#
#        review_scores_valuenan  licensenan  reviews_per_monthnan
# 17188                       1           1                     1
# 9902                        0           1                     0
# 17796                       1           1                     1
# 16947                       1           1                     1
# 18192                       1           1                     1

# %% [markdown]
# ### Selection of features

# %%
selected_feat =['neighbourhood', 
       'property_type', 'room_type', 'accommodates', 'bedrooms', 'beds', 'bed_type',
      'extra_people', 'availability_365', 'instant_bookable', 
        'host_is_superhost', 'number_of_reviews', 'review_scores_rating', 'price']
dataset=dataset[selected_feat]
dataset.head(4)
# Out:
#        neighbourhood  property_type  room_type  accommodates  bedrooms  beds  \
# 17188             19              3          0             2       1.0   1.0
# 9902               9              0          2             4       0.0   1.0
# 17796             20              2          2             4       2.0   2.0
# 16947             19              0          0             2       1.0   1.0
#
#        bed_type  extra_people  availability_365  instant_bookable  \
# 17188         1             4                 0                 0
# 9902          1             4                 0                 0
# 17796         1             4               364                 0
# 16947         1             4               180                 0
#
#        host_is_superhost  number_of_reviews  review_scores_rating  price
# 17188                  1                  0                  96.0   63.0
# 9902                   1                  3                  93.0   52.0
# 17796                  1                  0                  96.0  118.0
# 16947                  2                  0                  96.0   75.0

# %% [markdown]
# ### Features Scaling

# %% [markdown]
# Because we have different units of measure and different magnitude in each feature, that's why, it's important to use scaling, in order to help more the regression ML algorithm to be more efficient

# %%
# Normalise Dataframe 
feature_scale=[feature for feature in dataset.columns if feature not in ['price']]
data = pd.DataFrame()
for feature in feature_scale:
    data[feature] = (dataset[feature] - dataset[feature].mean())/ (dataset[feature].std())

data.insert(loc=1, column='price', value=dataset['price'])
dataset = data.copy()
dataset.head()
# Out:
#        neighbourhood  price  property_type  room_type  accommodates  bedrooms  \
# 17188       0.780457   63.0       1.718538  -1.586789     -0.629797 -0.392041
# 9902       -0.829453   52.0      -0.492949   0.640235      0.188997 -1.349452
# 17796       0.941448  118.0       0.981376   0.640235      0.188997  0.565371
# 16947       0.780457   75.0      -0.492949  -1.586789     -0.629797 -0.392041
# 18192      -0.507471   25.0       0.981376  -1.586789     -1.039194 -0.392041
#
#            beds  bed_type  extra_people  availability_365  instant_bookable  \
# 17188 -0.545363  0.103171      -0.10214         -0.828289         -1.104263
# 9902  -0.545363  0.103171      -0.10214         -0.828289         -1.104263
# 17796  0.107181  0.103171      -0.10214          2.096689         -1.104263
# 16947 -0.545363  0.103171      -0.10214          0.618129         -1.104263
# 18192  0.107181  0.103171      -0.10214         -0.522934         -1.104263
#
#        host_is_superhost  number_of_reviews  review_scores_rating
# 17188          -0.480543          -0.500030              0.241164
# 9902           -0.480543          -0.435664             -0.134827
# 17796          -0.480543          -0.500030              0.241164
# 16947           2.074120          -0.500030              0.241164
# 18192          -0.480543          -0.500030              0.241164

# %%
x_train = dataset[feature_scale]
y_train = np.log10(dataset['price'].values)

# %% [markdown]
# # Test set Feature engineering

# %%
dataset_test = pd.DataFrame()
dataset_test = test.copy()

# 1 - step make the list of Categorial features wich has missing values 
features_with_NAN = [feature for feature in dataset_test.columns if dataset_test[feature].isnull().sum()>1 and dataset_test[feature].dtypes=='O']


## Replace missing value with a new label ('Missing')
def replace_cat_feature(dataset_test,features_with_NAN):
    data=dataset_test.copy()
    data[features_with_NAN]=data[features_with_NAN].fillna('Missing')
    return data

datset_test=replace_cat_feature(dataset_test,features_with_NAN)

## 2 - step make the list of Categorial features wich has missing values 
features_numerical_with_NAN = [feature for feature in montreal_listing.columns if montreal_listing[feature].isnull().sum()>1 and montreal_listing[feature].dtypes !='O']
 
## Replacing the numerical Missing Values
for feature in features_numerical_with_NAN:
    ## We will replace by using median since there are outliers
    median_value=dataset_test[feature].median()
    
    ## create a new feature to capture nan values
    dataset_test[feature+'nan']=np.where(datset_test[feature].isnull(),1,0)
    dataset_test[feature].fillna(median_value,inplace=True)    
    

## Not interesting features
## drop 100% features_numerical_with_NAN nan values 
datset_test.drop(['thumbnail_url','medium_url','xl_picture_url','neighbourhood_group_cleansed','license'],axis=1,inplace=True)

## drop host_since
datset_test.drop(['host_since'],axis=1,inplace=True)

## drop Not interesting features
datset_test.drop(['id','listing_url','scrape_id','last_scraped', 'picture_url', 'host_url', 'host_name','host_thumbnail_url','host_picture_url','state', 'calendar_last_scraped','first_review', 'last_review'],axis=1,inplace=True)  

## Handling Rare Categorical Feature

categorical_features=[feature for feature in dataset_test.columns if dataset_test[feature].dtype=='O']

for feature in categorical_features:
    temp=dataset_test.groupby(feature)['price'].count()/len(dataset_test)
    temp_df=temp[temp>0.01].index
    dataset_test[feature]=np.where(dataset_test[feature].isin(temp_df),dataset_test[feature],'Rare_var')

## Handele categorical Features   

for feature in categorical_features:
    labels_ordered=dataset_test.groupby([feature])['price'].mean().sort_values().index
    labels_ordered={k:i for i,k in enumerate(labels_ordered,0)}
    dataset_test[feature]=dataset_test[feature].map(labels_ordered)
    
## Selection of features

selected_feat =['neighbourhood', 
       'property_type', 'room_type', 'accommodates', 'bedrooms', 'beds', 'bed_type',
      'extra_people', 'availability_365', 'instant_bookable', 
        'host_is_superhost', 'number_of_reviews', 'review_scores_rating', 'price']

dataset_test=dataset_test[selected_feat]

## Features Scaling
# Normalise Dataframe 
feature_scale=[feature for feature in dataset_test.columns if feature not in ['price']]
data = pd.DataFrame()
for feature in feature_scale:
    data[feature] = (dataset_test[feature] - dataset_test[feature].mean())/ (dataset_test[feature].std())

data.insert(loc=1, column='price', value=dataset_test['price'])
dataset_test = data.copy()

x_test = dataset_test[feature_scale]
y_test = np.log10(dataset_test['price'].values)

# %% [markdown]
# ### Linear Regression Model

# %%
from sklearn.linear_model import LinearRegression
from sklearn.metrics import * # import all metrics

#Prepare a Linear Regression (LR) Model and Fitting model with trainig data
reg=LinearRegression()
reg.fit(x_train,y_train)
y_pred=reg.predict(x_test)

y_test = np.round(10 ** y_test, 0)
y_pred = np.round(10 ** y_pred, 0)
df = pd.DataFrame({'Actual': y_test, 'Predicted': y_pred})
df.head()
# Out:
#    Actual  Predicted
# 0    96.0      144.0
# 1    80.0      150.0
# 2   281.0      202.0
# 3    75.0       58.0
# 4    61.0       61.0

# %%
print('Results of the evaluation of our LR model with different Measures:')
print('R2 (score):',round(r2_score(y_test, y_pred),2))
print('MAE:', round(mean_absolute_error(y_test, y_pred),2))
print('MSE:', round(mean_squared_error(y_test, y_pred),2))
print('RMSE:', round(np.sqrt(mean_squared_error(y_test, y_pred)),2))
print('Median ABS Error:', round(median_absolute_error(y_test, y_pred),2))
# Out:
# Results of the evaluation of our LR model with different Measures:
# R2 (score): 0.29
# MAE: 48.48
# MSE: 21632.8
# RMSE: 147.08
# Median ABS Error: 21.0

# %%
sns.regplot(x=np.log10(y_test),y=np.log10(y_pred),fit_reg=True)
